# %%
from __future__ import print_function
import datetime
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import datetime     
import numpy as np
# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/calendar',
          'https://www.googleapis.com/auth/spreadsheets.readonly'
]

calendarID="c_822m07aktpjne3gfbr7cj8gjks@group.calendar.google.com"

"""Shows basic usage of the Google Calendar API.
Prints the start and name of the next 10 events on the user's calendar.
"""
creds = None
# The file token.pickle stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.pickle'):
    with open('token.pickle', 'rb') as token:
        creds = pickle.load(token)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.pickle', 'wb') as token:
        pickle.dump(creds, token)

service = build('calendar', 'v3', credentials=creds)

# Call the Calendar API
now = datetime.datetime.utcnow().isoformat() + 'Z' # 'Z' indicates UTC time
print('Getting the upcoming 10 events')
events_result = service.events().list(calendarId=calendarID, timeMin=now,
                                    maxResults=10, singleEvents=True,
                                    orderBy='startTime').execute()
events = events_result.get('items', [])

if not events:
    print('No upcoming events found.')
for event in events:
    start = event['start'].get('dateTime', event['start'].get('date'))
    print(start, event['summary'])
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=522458309582-8h9prq3p322k47r9iv8adb5i18d7qupl.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60029%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fspreadsheets.readonly&state=dS8qrTxQWFOdodRd5Hu7YOxeczUhoC&access_type=offline
# Getting the upcoming 10 events
# No upcoming events found.

# %%
creds

# %%
from googleapiclient.discovery import build
def pull_sheet_data(SCOPES,SPREADSHEET_ID,RANGE_NAME):
    
    service = build('sheets', 'v4', credentials=creds)
    sheet = service.spreadsheets()
    result = sheet.values().get(
        spreadsheetId=SPREADSHEET_ID,
        range=RANGE_NAME).execute()
    values = result.get('values', [])
    
    if not values:
        print('No data found.')
    else:
        rows = sheet.values().get(spreadsheetId=SPREADSHEET_ID,
                                  range=RANGE_NAME).execute()
        data = rows.get('values')
        print("COMPLETE: Data copied")
        return data
data = pull_sheet_data(SCOPES, '1FShxZd3UCr0qTsrGcoq9VZ6_u_UmXisb3jkp-nBMdeA', 'Computer_Readable!A1:G')
# Out:
# COMPLETE: Data copied

# %%
data[1:]
# Out:
# [['9/18/2021',
#   '10 am - 11 am',
#   'WCT',
#   'wct-instructors, students2024',
#   'Writing and Critical Thinking',
#   '4',
#   'lf4bcot0ivuusmgm0ntf8a89k8'],
#  ['9/18/2021',
#   '11 am - 12 pm',
#   'Math Matters',
#   'math-instructors, students2024',
#   'Math Matters',
#   '3',
#   'sijcp0a0cu6uvi3hh3ltup69l0'],
#  ['9/18/2021',
#   '10 am - 12 pm',
#   'Test prep',
#   'testprep-instructors, students2023',
#   'Test Prep',
#   '5',
#   'pal4jl52k8v99t3am7i8r392o8'],
#  ['9/18/2021',
#   '10 am - 12 pm',
#   'Senior Enrichment',
#   'senior-enrichment-instructors, students2022',
#   'Senior Enrichment',
#   '6',
#   '28s65j16q97h6jlevui5re92v8'],
#  ['9/18/2021',
#   '12 pm - 2 pm',
#   'Sophomore Mentoring',
#   '2024mentors, students2024',
#   'Sophomore Mentoring',
#   '7',
#   'f9h4kh6hupavaiqnhkohgajkk0'],
#  ['9/18/2021',
#   '12 pm - 2 pm',
#   'Junior Mentoring',
#   '2023mentors, students2023',
#   'Junior Mentoring',
#   '8',
#   'fqpd09cq330s1mhdvvo3mue1fg'],
#  ['9/18/2021',
#   '12 pm - 2 pm',
#   'Senior Mentoring',
#   '2022mentors, students2022',
#   'Senior Mentoring',
#   '9',
#   '6kkure992tf2ku36s83bl2c3lo'],
#  ['9/18/2021',
#   '2:30 pm - 4 pm',
#   'ec',
#   'ec',
#   'EC Meeting',
#   '1',
#   'skv4c8qt1irbje9folff645ib4'],
#  ['9/25/2021',
#   '10 am - 11 am',
#   'WCT',
#   'wct-instructors, students2024',
#   'Writing and Critical Thinking',
#   '4',
#
2022',
#   '12 pm - 2 pm',
#   'Sophomore Mentoring',
#   '2024mentors, students2024',
#   'Sophomore Mentoring',
#   '7',
#   '-'],
#  ['2/26/2022',
#   '12 pm - 2 pm',
#   'Junior Mentoring',
#   '2023mentors, students2023',
#   'Junior Mentoring',
#   '8',
#   '-'],
#  ['2/26/2022',
#   '12 pm - 2 pm',
#   'Senior Mentoring',
#   '2022mentors, students2022',
#   'Senior Mentoring',
#   '9',
#   '-'],
#  ['2/26/2022', '2:30 pm - 4 pm', 'ec', 'ec', 'EC Meeting', '1', '-'],
#  ['3/5/2022',
#   '10 am - 11 am',
#   'WCT',
#   'wct-instructors, students2024',
#   'Writing and Critical Thinking',
#   '4',
#   '-'],
#  ['3/5/2022',
#   '11 am - 12 pm',
#   'Math Matters',
#   'math-instructors, students2024',
#   'Math Matters',
#   '3',
#   '-'],
#  ['3/5/2022',
#   '10 am - 12 pm',
#   'Test prep',
#   'testprep-instructors, students2023',
#   'Test Prep',
#   '5',
#   '-'],
#  ['3/5/2022',
#   '10 am - 12 pm',
#   'Senior Enrichment',
#   'senior-enrichment-instructors, students2022',
#   'Senior Enrichment',
#   '6',
#   '-'],
#  ['3/5/2022',
#   '12 pm - 2 pm',
#   'Sophomore Mentoring',
#   '2024mentors, students2024',
#   'Sophomore Mentoring',
#   '7',
#   '-'],
#  ['3/5/2022',
#   '12 pm - 2 pm',
#   'Junior Mentoring',
#   '2023mentors, students2023',
#   'Junior Mentoring',
#   '8',
#   '-'],
#  ['3/5/2022',
#   '12 pm - 2 pm',
#   'Senior Mentoring',
#   '2022mentors, students2022',
#   'Senior Mentoring',
#   '9',
#   '-'],
#  ['3/12/2022',
#   '10 am - 11 am',
#   'WCT',
#   'wct-instructors, students2024',
#   'Writing and Critical Thinking',
#   '4',
#   '-'],
#  ['3/12/2022',
#   '11 am - 12 pm',
#   'Math Matters',
#   'math-instructors, students2024',
#   'Math Matters',
#   '3',
#   '-'],
#  ['3/12/2022',
#   '10 am - 12 pm',
#   'Test prep',
#   'testprep-instructors, students2023',
#   'Test Prep',
#   '5',
#   '-'],
#  ['3/12/2022',
#   '10 am - 12 pm',
#   'Senior Enrichment',
#   'senior-enrichment-instructors, students2022',
#   'Senior Enrichment',
#   '6',
#   '-'],
#  ['3/12/2022',
#   '12 pm - 2 pm',
#   'Sophomore Mentoring',
#   '2024mentors, students2024',
#   'Sophomore Mentoring',
#   '7',
#   '-'],
#  ['3/12/2022',
#   '12 pm - 2 pm',
#   'Junior Mentoring',
#   '2023mentors, students2023',
#   'Junior Mentoring',
#   '8',
#   '-'],
#  ['3/12/2022',
#   '12 pm - 2 pm',
#   'Senior Mentoring',
#   '2022mentors, students2022',
#   'Senior Mentoring',
#   '9',
#   '-'],
#  ['3/19/2022',
#   '10 am - 11 am',
#   'WCT',
#   'wct-instructors, students2024',
#   'Writing and Critical Thinking',
#   '4',
#   '-'],
#  ['3/19/2022',
#   '11 am - 12 pm',
#   'Math Matters',
#   'math-instructors, students2024',
#   'Math Matters',
#   '3',
#   '-'],
#  ['3/19/2022',
#   '10 am - 12 pm',
#   'Test prep',
#   'testprep-instructors, students2023',
#   'Test Prep',
#   '5',
#   '-'],
#  ['3/19/2022',
#   '10 am - 12 pm',
#   'Senior Enrichment',
#   'senior-enrichment-instructors, students2022',
#   'Senior Enrichment',
#   '6',
#   '-'],
#  ['3/19/2022',
#   '12 pm - 2 pm',
#   'Sophomore Mentoring',
#   '2024mentors, students2024',
#   'Sophomore Mentoring',
#   '7',
#   '-'],
#  ['3/19/2022',
#   '12 pm - 2 pm',
#   'Junior Mentoring',
#   '2023mentors, students2023',
#   'Junior Mentoring',
#   '8',
#   '-'],
#  ['3/19/2022',
#   '12 pm - 2 pm',
#   'Senior Mentoring',
#   '2022mentors, students2022',
#   'Senior Mentoring',
#   '9',
#   '-'],
#  ['3/26/2022',
#   '10 am - 11 am',
#   'WCT',
#   'wct-instructors, students2024',
#   'Writing and Critical Thinking',
#   '4',
#   '-'],
#  ['3/26/2022',
#   '11 am - 12 pm',
#   'Math Matters',
#   'math-instructors, students2024',
#   'Math Matters',
#   '3',
#   '-'],
#  ['3/26/2022',
#   '10 am - 12 pm',
#   'Test prep',
#   'testprep-instructors, students2023',
#   'Test Prep',
#   '5',
#   '-'],
#  ['3/26/2022',
#   '10 am - 12 pm',
#   'Senior Enrichment',
#   'senior-enrichment-instructors, students2022',
#   'Senior Enrichment',
#   '6',
#   '-'],
#  ['3/26/2022',
#   '12 pm - 2 pm',
#   'Sophomore Mentoring',
#   '2024mentors, students2024',
#   'Sophomore Mentoring',
#   '7',
#   '-'],
#  ['3/26/2022',
#   '12 pm - 2 pm',
#   'Junior Mentoring',
#   '2023mentors, students2023',
#   'Junior Mentoring',
#   '8',
#   '-'],
#  ['3/26/2022',
#   '12 pm - 2 pm',
#   'Senior Mentoring',
#   '2022mentors, students2022',
#   'Senior Mentoring',
#   '9',
#   '-'],
#  ['3/26/2022', '2:30 pm - 4 pm', 'ec', 'ec', 'EC Meeting', '1', '-'],
#  ['4/2/2022',
#   '10 am - 11 am',
#   'WCT',
#   'wct-instructors, students2024',
#   'Writing and Critical Thinking',
#   '4',
#   '-'],
#  ['4/2/2022',
#   '11 am - 12 pm',
#   'Math Matters',
#   'math-instructors, students2024',
#   'Math Matters',
#   '3',
#   '-'],
#  ['4/2/2022',
#   '10 am - 12 pm',
#   'Test prep',
#   'testprep-instructors, students2023',
#   'Test Prep',
#   '5',
#   '-'],
#  ['4/2/2022',
#   '10 am - 12 pm',
#   'Senior Enrichment',
#   'senior-enrichment-instructors, students2022',
#   'Senior Enrichment',
#   '6',
#   '-'],
#  ['4/2/2022',
#   '12 pm - 2 pm',
#   'Sophomore Mentoring',
#   '2024mentors, students2024',
#   'Sophomore Mentoring',
#   '7',
#   '-'],
#  ['4/2/2022',
#   '12 pm - 2 pm',
#   'Junior Mentoring',
#   '2023mentors, students2023',
#   'Junior Mentoring',
#   '8',
#   '-'],
#  ['4/2/2022',
#   '12 pm - 2 pm',
#   'Senior Mentoring',
#   '2022mentors, students2022',
#   'Senior Mentoring',
#   '9',
#   '-'],
#  ['4/16/2022',
#   '10 am - 11 am',
#   'WCT',
#   'wct-instructors, students2024',
#   'Writing and Critical Thinking',
#   '4',
#   '-'],
#  ['4/16/2022',
#   '11 am - 12 pm',
#   'Math Matters',
#   'math-instructors, students2024',
#   'Math Matters',
#   '3',
#   '-'],
#  ['4/16/2022',
#   '10 am - 12 pm',
#   'Test prep',
#   'testprep-instructors, students2023',
#   'Test Prep',
#   '5',
#   '-'],
#  ['4/16/2022',
#   '10 am - 12 pm',
#   'Senior Enrichment',
#   'senior-enrichment-instructors, students2022',
#   'Senior Enrichment',
#   '6',
#   '-'],
#  ['4/16/2022',
#   '12 pm - 2 pm',
#   'Sophomore Mentoring',
#   '2024mentors, students2024',
#   'Sophomore Mentoring',
#   '7',
#   '-'],
#  ['4/16/2022',
#   '12 pm - 2 pm',
#   'Junior Mentoring',
#   '2023mentors, students2023',
#   'Junior Mentoring',
#   '8',
#   '-'],
#  ['4/16/2022',
#   '12 pm - 2 pm',
#   'Senior Mentoring',
#   '2022mentors, students2022',
#   'Senior Mentoring',
#   '9',
#   '-'],
#  ['4/23/2022',
#   '10 am - 11 am',
#   'WCT',
#   'wct-instructors, students2024',
#   'Writing and Critical Thinking',
#   '4',
#   '-'],
#  ['4/23/2022',
#   '11 am - 12 pm',
#   'Math Matters',
#   'math-instructors, students2024',
#   'Math Matters',
#   '3',
#   '-'],
#  ['4/23/2022',
#   '10 am - 12 pm',
#   'Test prep',
#   'testprep-instructors, students2023',
#   'Test Prep',
#   '5',
#   '-'],
#  ['4/23/2022',
#   '10 am - 12 pm',
#   'Senior Enrichment',
#   'senior-enrichment-instructors, students2022',
#   'Senior Enrichment',
#   '6',
#   '-'],
#  ['4/23/2022',
#   '12 pm - 2 pm',
#   'Sophomore Mentoring',
#   '2024mentors, students2024',
#   'Sophomore Mentoring',
#   '7',
#   '-'],
#  ['4/23/2022',
#   '12 pm - 2 pm',
#   'Junior Mentoring',
#   '2023mentors, students2023',
#   'Junior Mentoring',
#   '8',
#   '-'],
#  ['4/23/2022',
#   '12 pm - 2 pm',
#   'Senior Mentoring',
#   '2022mentors, students2022',
#   'Senior Mentoring',
#   '9',
#   '-'],
#  ['4/30/2022',
#   '10 am - 11 am',
#   'WCT',
#   'wct-instructors, students2024',
#   'Writing and Critical Thinking',
#   '4',
#   '-'],
#  ['4/30/2022',
#   '11 am - 12 pm',
#   'Math Matters',
#   'math-instructors, students2024',
#   'Math Matters',
#   '3',
#   '-'],
#  ['4/30/2022',
#   '10 am - 12 pm',
#   'Test prep',
#   'testprep-instructors, students2023',
#   'Test Prep',
#   '5',
#   '-'],
#  ['4/30/2022',
#   '10 am - 12 pm',
#   'Senior Enrichment',
#   'senior-enrichment-instructors, students2022',
#   'Senior Enrichment',
#   '6',
#   '-'],
#  ['4/30/2022',
#   '12 pm - 2 pm',
#   'Sophomore Mentoring',
#   '2024mentors, students2024',
#   'Sophomore Mentoring',
#   '7',
#   '-'],
#  ['4/30/2022',
#   '12 pm - 2 pm',
#   'Junior Mentoring',
#   '2023mentors, students2023',
#   'Junior Mentoring',
#   '8',
#   '-'],
#  ['4/30/2022',
#   '12 pm - 2 pm',
#   'Senior Mentoring',
#   '2022mentors, students2022',
#   'Senior Mentoring',
#   '9',
#   '-'],
#  ['4/30/2022', '2:30 pm - 4 pm', 'ec', 'ec', 'EC Meeting', '1', '-'],
#  ['5/7/2022',
#   '10 am - 11 am',
#   'WCT',
#   'wct-instructors, students2024',
#   'Writing and Critical Thinking',
#   '4',
#   '-'],
#  ['5/7/2022',
#   '11 am - 12 pm',
#   'Math Matters',
#   'math-instructors, students2024',
#   'Math Matters',
#   '3',
#   '-'],
#  ['5/7/2022',
#   '10 am - 12 pm',
#   'Test prep',
#   'testprep-instructors, students2023',
#   'Test Prep',
#   '5',
#   '-'],
#  ['5/7/2022',
#   '10 am - 12 pm',
#   'Senior Enrichment',
#   'senior-enrichment-instructors, students2022',
#   'Senior Enrichment',
#   '6',
#   '-'],
#  ['5/7/2022',
#   '12 pm - 2 pm',
#   'Sophomore Mentoring',
#   '2024mentors, students2024',
#   'Sophomore Mentoring',
#   '7',
#   '-'],
#  ['5/7/2022',
#   '12 pm - 2 pm',
#   'Junior Mentoring',
#   '2023mentors, students2023',
#   'Junior Mentoring',
#   '8',
#   '-'],
#  ['5/7/2022',
#   '12 pm - 2 pm',
#   'Senior Mentoring',
#   '2022mentors, students2022',
#   'Senior Mentoring',
#   '9',
#   '-'],
#  ['5/14/2022', '10 am - 1 pm', 'ec', 'active', 'Graduation', '1', '-']]

# %%
import pandas as pd
df = pd.DataFrame(data[1:], columns=data[0])

# %%
df['start']=df.Time.str.split(' - ').map(lambda x: x[0])
df['end']=df.Time.str.split(' - ').map(lambda x: x[1])

# %%
df
# Out:
#           Date           Time  Calendar Assignment  \
# 0    9/18/2021  10 am - 11 am                  WCT
# 1    9/18/2021  11 am - 12 pm         Math Matters
# 2    9/18/2021  10 am - 12 pm            Test prep
# 3    9/18/2021  10 am - 12 pm    Senior Enrichment
# 4    9/18/2021   12 pm - 2 pm  Sophomore Mentoring
# ..         ...            ...                  ...
# 179   5/7/2022  10 am - 12 pm    Senior Enrichment
# 180   5/7/2022   12 pm - 2 pm  Sophomore Mentoring
# 181   5/7/2022   12 pm - 2 pm     Junior Mentoring
# 182   5/7/2022   12 pm - 2 pm     Senior Mentoring
# 183  5/14/2022   10 am - 1 pm                   ec
#
#                                 Share with group  \
# 0                  wct-instructors, students2024
# 1                 math-instructors, students2024
# 2             testprep-instructors, students2023
# 3    senior-enrichment-instructors, students2022
# 4                      2024mentors, students2024
# ..                                           ...
# 179  senior-enrichment-instructors, students2022
# 180                    2024mentors, students2024
# 181                    2023mentors, students2023
# 182                    2022mentors, students2022
# 183                                       active
#
#                        Event Title Color             calendarEventID  start  \
# 0    Writing and Critical Thinking     4  lf4bcot0ivuusmgm0ntf8a89k8  10 am
# 1                     Math Matters     3  sijcp0a0cu6uvi3hh3ltup69l0  11 am
# 2                        Test Prep     5  pal4jl52k8v99t3am7i8r392o8  10 am
# 3                Senior Enrichment     6  28s65j16q97h6jlevui5re92v8  10 am
# 4              Sophomore Mentoring     7  f9h4kh6hupavaiqnhkohgajkk0  12 pm
# ..                             ...   ...                         ...    ...
# 179              Senior Enrichment     6                           -  10 am
# 180            Sophomore Mentoring     7                           -  12 pm
# 181               Junior Mentoring     8                           -  12 pm
# 182               Senior Mentoring     9                           -  12 pm
# 183                     Graduation     1                           -  10 am
#
#        end
# 0    11 am
# 1    12 pm
# 2    12 pm
# 3    12 pm
# 4     2 pm
# ..     ...
# 179  12 pm
# 180   2 pm
# 181   2 pm
# 182   2 pm
# 183   1 pm
#
# [184 rows x 9 columns]

# %%
eventservice=service.events()

# %%
import time
for k,row in df.iterrows():
    try:
        starttime=datetime.datetime.strptime(row.Date + " " + row.start, '%m/%d/%Y %I:%M %p')
    except ValueError:
        starttime=datetime.datetime.strptime(row.Date + " " + row.start, '%m/%d/%Y %I %p')
        
    try:
        endtime=datetime.datetime.strptime(row.Date + " " + row.end, '%m/%d/%Y %I:%M %p')
    except ValueError:
        endtime=datetime.datetime.strptime(row.Date + " " + row.end, '%m/%d/%Y %I %p')
    print(starttime, endtime)
    body={
        "description": row['Event Title'],
        "summary":  row['Event Title'],
        "start":{
            "dateTime": starttime.isoformat(),
            "timeZone": "America/Los_Angeles"
        },
        "end":{
            "dateTime": endtime.isoformat(),
            "timeZone": "America/Los_Angeles"
        },
        "colorId": f"{row.Color}",
        "guestsCanInviteOthers": False

    }
    if row.get("calendarEventID", "-")=="-":
    #    print('inserting')
        r=eventservice.insert(calendarId=calendarID,
                             body=body)
        response=r.execute()
        #print(response)
        df.loc[k, 'calendarEventID']=response['id']
        time.sleep(.1)
# Out:
# 2021-09-18 10:00:00 2021-09-18 11:00:00
# 2021-09-18 11:00:00 2021-09-18 12:00:00
# 2021-09-18 10:00:00 2021-09-18 12:00:00
# 2021-09-18 10:00:00 2021-09-18 12:00:00
# 2021-09-18 12:00:00 2021-09-18 14:00:00
# 2021-09-18 12:00:00 2021-09-18 14:00:00
# 2021-09-18 12:00:00 2021-09-18 14:00:00
# 2022-04-23 10:00:00 2022-04-23 12:00:00
# 2022-04-23 12:00:00 2022-04-23 14:00:00
# 2022-04-23 12:00:00 2022-04-23 14:00:00
# 2022-04-23 12:00:00 2022-04-23 14:00:00
# 2022-04-30 10:00:00 2022-04-30 11:00:00
# 2022-04-30 11:00:00 2022-04-30 12:00:00
# 2022-04-30 10:00:00 2022-04-30 12:00:00
# 2022-04-30 10:00:00 2022-04-30 12:00:00
# 2022-04-30 12:00:00 2022-04-30 14:00:00
# 2022-04-30 12:00:00 2022-04-30 14:00:00
# 2022-04-30 12:00:00 2022-04-30 14:00:00
# 2022-04-30 14:30:00 2022-04-30 16:00:00
# 2022-05-07 10:00:00 2022-05-07 11:00:00
# 2022-05-07 11:00:00 2022-05-07 12:00:00
# 2022-05-07 10:00:00 2022-05-07 12:00:00
# 2022-05-07 10:00:00 2022-05-07 12:00:00
# 2022-05-07 12:00:00 2022-05-07 14:00:00
# 2022-05-07 12:00:00 2022-05-07 14:00:00
# 2022-05-07 12:00:00 2022-05-07 14:00:00
# 2022-05-14 10:00:00 2022-05-14 13:00:00

# %%
df.to_csv('calendar_IDs.csv')

# %%
for k,row in df.iterrows():
    if 'ec' in row['Share with group']:
        event = eventservice.get(calendarId=calendarID, eventId=row.calendarEventID).execute()
        attendees=event.get('attendees',[])
        try:
            ecinvite=next(a for a in attendees if a['email']=='ec')
        except StopIteration:
            ecinvite = {
                'email': 'ec@mindsmatterseattle.org'
            }
            attendees.append(ecinvite)
        
        event['attendees'] =  attendees
        
        eventservice.update(calendarId=calendarID, eventId=row.calendarEventID, body=event).execute()

# %%
for k,row in df.iterrows():
    emails=map(lambda x: x.replace(' ','') ,row['Share with group'].split(','))
    event = eventservice.get(calendarId=calendarID, eventId=row.calendarEventID).execute()
    attendees=event.get('attendees',[])
    for email in emails:
        try:
            invite=next(a for a in attendees if a['email']==email + "@mindsmatterseattle.org")
        except StopIteration:
            print(f'inviting {email} to {event["summary"]}')
            invite = {
                'email': f'{email}@mindsmatterseattle.org'
            }
            attendees.append(invite)

    event['attendees'] =  attendees 
    eventservice.update(calendarId=calendarID, eventId=row.calendarEventID, body=event).execute()
# Out:
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting board to EC + Board Meeting
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting active to Holiday Party
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting wct-instructors to Writing and Critical Thinking
# inviting students2024 to Writing and Critical Thinking
# inviting math-instructors to Math Matters
# inviting students2024 to Math Matters
# inviting testprep-instructors to Test Prep
# inviting students2023 to Test Prep
# inviting senior-enrichment-instructors to Senior Enrichment
# inviting students2022 to Senior Enrichment
# inviting 2024mentors to Sophomore Mentoring
# inviting students2024 to Sophomore Mentoring
# inviting 2023mentors to Junior Mentoring
# inviting students2023 to Junior Mentoring
# inviting 2022mentors to Senior Mentoring
# inviting students2022 to Senior Mentoring
# inviting active to Graduation

# %%
df.to_csv('calendar_events.csv')

# %%
np.isnan(df.loc[244, 'calendarEventID'])
# Out:
# True
